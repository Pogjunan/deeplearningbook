# %% [markdown]
# # `[1] introduction`

# %% [markdown]
# 안녕하세요, 전준한입니다. 이 책은 deeplearningbook.org 에 대한 최대한 한국어로 요약해놓은 강의노트입니다.

# %% [markdown]
# 초보/숙련자 들이 쉽게 읽을 수 있도록 최대한 번역해보았고 저도 이해를 위한 노력을 곳곳에 자취를 남기면서 번역을 시도하였습니다. 이 책을 다 읽으시면 꽤나 도움이 많이 될 거 같습니다.
# <br>
# 제가 만든 강의노트만 읽으셔도 되고 영어에 익숙하시다면 deepelearningbook.org 를 보면서 이해가 안되는 부분을 제가 만약 정리해놓았다면 참고하시면서 이해하시는데 도움이 될 수 있습니다.
# <br>
# `[1] intro` 는 가벼운 용어에 대한 소개입니다. 앞으로 딥러닝에 관해 기초이론부터 다 소개가 되어있습니다. 초보자도 읽을 수 있겠지만 machine learning 이나 통계학을 한 번도 접해보지 않은 분은 조금 비추천 드리고 github.com/Pogjunan 에 있는 기초 연습부터 보는 것을 추천드립니다!

# %% [markdown]
# ### `Chapter 1` <br>
# `IntroductionInventors have long dreamed of creating machines that think. This desire datesback to at least the time of ancient Greece. The mythical ﬁgures Pygmalion,Daedalus, and Hephaestus may all be interpreted as legendary inventors, andGalatea, Talos, and Pandora may all be regarded as artiﬁcial life (Ovid and Martin,2004; Sparkes, 1996; Tandy, 1997).`

# %% [markdown]
# ![image.png](attachment:b7d08515-2912-4610-b20a-09b9db16196f.png)

# %% [markdown]
# ### `Chapter 2` : $Linear$ $ Algebra$ <br>
# - If you are already familiar with linear algebra, feel free to skip this chapter.

# %% [markdown]
# 1 **Scalars** : A scalar is just a single number , which are usually arrays of multiple numbers. We write scalars in $italics$. We usually give scalars lowercase variable names.
# <br>
# example : “Let $ s ∈ R$ be the slope of the line” =  deﬁning a real-valued scalar <br>
# example2 :  “Let $ n ∈ N $be the number of units,” = deﬁning a natural number scalar <br>
# - 중요한건 여기서 s 와 n 이 스칼라라는 점이다.

# %% [markdown]
# 2 **Vectors** : A vector is an array of numbers.The numbers are arranged in order.
# - 벡터는 순서가 중요한 숫자들이 배열로 이루어진 집합이다.
# <br>
#
# Typically we give vectors lowercase names in bold typeface, such as **$x$** (bold체)
# <br>
# The ﬁrst element of **$x$** is$x_1$, the second element is$x_2$

# %% [markdown]
# ![image.png](attachment:ab096ba6-d91f-45c2-96ef-0d12f2b45772.png)
# <br>
# 볼드체 x 는 vector 이고 그의 element 들은 볼드체가 아닌 이탈릭체 사용

# %% [markdown]
# 3 **Metrices** : A matrix is a 2-D array of numbers, so each element is identiﬁedby two indices instead of just one. `two indices :  like (3,2)`

# %% [markdown]
# 4 **Tensors** : we will need an array with more than two axes. An array of numbers arranged on a regular grid with avariable number of axes is known as a tensor.
# (일반 그리드에 배열된 숫자 배열을 텐서라고 합니다.)

# %% [markdown]
# # `(1) Linear Dependence and Span`

# %% [markdown]
# $$ z = \alpha \mathbf{x} + (1-\alpha)\mathbf{y} $$

# %% [markdown]
# - **span** : 벡터 $V_1,V_2,.. , V_n$ 에 대해
# <br>

# %% [markdown]
# $\text{span}\{V_1, V_2, \ldots, V_n\} = \{C_1V_1 + C_2V_2 + \ldots + C_nV_n \mid C_1, C_2, \ldots, C_n \in \mathbb{R}\}$
# `-` 벡터들의 선형결합으로 만드는 벡터공간.\
#
# <br>
#
# 스칼라 $c_1, c_2$에 대해 $c_1 \begin{bmatrix} 1 \ 0 \end{bmatrix} + c_2 \begin{bmatrix} 0 \ 1 \end{bmatrix}$로 표현될 수 있는 평면 상의 모든 벡터를 나타냅니다.

# %% [markdown]
# - Span Theorem : $\mathbb{R^n}\ $ 의 벡터 $V_1,...,V_k$ 에 대해 $\text{span}\{V_1,V_2, ... ,V_k\} $ 는 $\mathbb{R^n}\ $ 의 부분공간이다.

# %% [markdown]
# Frobenius norm 식:
# Frobenius 노름은 행렬의 각 요소의 제곱의 합의 제곱근으로 정의됩니다. 수식은 다음과 같습니다:
# $$ \|A\|_F = \sqrt{\sum_{i=1}^M \sum_{j=1}^N |a_{ij}|^2} $$
#
# <br>
#
# ​이 노름은 행렬의 크기를 나타내는 방법입니다.
# <br>
# Dot Product와 각도 관련 식:
# $$\begin{equation}
# \mathbf{x}^T \mathbf{y} = \|\mathbf{x}\|_2 \|\mathbf{y}\|_2 \cos(\theta)
# \end{equation}$$
# `-` $||x||_2$ 는 2차원에서의 제곱근을 의미합니다. <br>
# `-` 비슷하게 위의 `F` 는 행렬의 크기를 나타내며 차원과 똑같이 작용됩니다.

# %% [markdown]
# ## `행렬 A의 의사 역행렬(pseudo-inverse)`  <br>
#
# A의 역행렬이 존재하지 않거나 정확한 역행렬을 계산하기 어려운 경우에 사용됩니다. 의사 역행렬은 Moore-Penrose 역행렬이라고도 불리며, 일반적으로 $A^+$
#  로 표기됩니다.
#
# 행렬
# A에 대한 의사 역행렬은 다음의 특성을 가지고 있습니다: <br>
# $A^+AA^+ = A^+$ <br>
# $AA^+A = A^+$
#
# <br>
# 의사 역행렬은 정확한 역행렬이 존재하지 않을 때, 또는 행렬이 풀랭크가 아닐 때 유용하게 사용됩니다.

# %% [markdown]
# ###  제가 알고 있는 일반화 역행렬(Generalized inverse) $A^{-}$
#  와 똑같아보이는것같은데 무슨 차이일까?
#  - GPT 에게 질문하였습니다.

# %% [markdown]
# ![image.png](attachment:af001498-8408-4fb5-a94c-919836af7e28.png)

# %% [markdown]
# # 구글 검색 (일반화역행렬과 의사역행렬의 차이)
#
# Generalized Inverse (일반화 역행렬): 이 용어는 행렬이 정방 행렬이 아닌 경우에도 역행렬과 유사한 역할을 수행하는 행렬을 지칭할 때 사용됩니다. 그러나 정확한 정의에 따라 generalized inverse는 여러 종류가 있습니다.
#
# Pseudoinverse (의사 역행렬): Pseudoinverse는 일반화 역행렬 중 하나로서, 정방 행렬이 아닌 행렬에 대한 역행렬과 유사한 역할을 하는 것을 의미합니다. 주로 특이값 분해(Singular Value Decomposition, SVD)를 사용하여 계산됩니다.
#
# `-` 결론 : 그냥 같은 것인가?

# %% [markdown]
# `-` 아니다! 참고
# https://www.sjsu.edu/faculty/guangliang.chen/Math250/lec6ginverse.pdf

# %% [markdown]
# ![image.png](attachment:2ab947fb-4577-4798-ad34-9ddcc55f1c05.png)
#
# - 일반화역행렬에 대한 정의
#
# - `Remark.` : 행렬 $A_mxn$ 는 항상 일반화 역행렬이 존재하고 유일하지 않고 여러개 존재할 수 있다.(might not be unique)

# %% [markdown]
# ![image.png](attachment:e3c4a6fa-6778-4005-b116-0291f52609b5.png)
#
# - 의사 역행렬에 대한 정의
# - `결정적으로` 더 많은 제약이 있는 일반화역행렬이라고 정의되었습니다.
#
# 위의 4가지가 성립하는 일반화역행렬입니다.
#
# 밑의 예시를 봅시다.
# ![image.png](attachment:83584d6f-57d6-4106-9973-d139ec13b2e4.png)
#
# 일반화역행렬이지만
# ![image.png](attachment:0328b651-272e-40fe-82d4-80eb5d77b9d3.png)
#
# 의사역행렬은 아닙니다.
#
# # 끝
